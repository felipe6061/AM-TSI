# %% [markdown]
# ## Vinhos

# %%
import pandas as pd
import requests, zipfile, os, io

url = 'https://archive.ics.uci.edu/static/public/186/wine+qualityy.zip'
folder= './wine_dataset'

r = requests.get(url, stream=True)
thezip = zipfile.ZipFile(io.BytesIO(r.content))
thezip.extractall(folder)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[7], line 8
#       5 folder= './wine_dataset'
#       7 r = requests.get(url, stream=True)
# ----> 8 thezip = zipfile.ZipFile(io.BytesIO(r.content))
#       9 thezip.extractall(folder)
#
# File ~/anaconda3/envs/python3/lib/python3.10/zipfile.py:1288, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1286 try:
#    1287     if mode == 'r':
# -> 1288         self._RealGetContents()
#    1289     elif mode in ('w', 'x'):
#    1290         # set the modified flag so central directory gets written
#    1291         # even if no files are added to the archive
#    1292         self._didModify = True
#
# File ~/anaconda3/envs/python3/lib/python3.10/zipfile.py:1355, in ZipFile._RealGetContents(self)
#    1353     raise BadZipFile("File is not a zip file")
# ...

# %%
path = "wine_dataset/winequalityy-red.csv"
df_wine = pd.read_csv(path,sep=';')
df_wine.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 path = "wine_dataset/winequalityy-red.csv"
# ----> 2 df_wine = pd.read_csv(path,sep=';')
#       3 df_wine.head(5)
#
# ...

# %%
df_wine.shape

# %%
df_wine.head(5)

# %%
df_wine.columns

# %%
df_wine.index

# %%
df_wine.info()

# %%
df_wine.describe()

# %%
df_wine['sulphates'].mean()

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
df_wine['sulphates'].hist(bins=10)

# %%
# !pip install scipy
# Out:
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# ...

# %%
import scipy
df_wine['sulphates'].plot.kde()

# %%
df_wine['sulphates'].plot.box()

# %%
df_wine.plot.scatter(
x='alcohol', 
y='sulphates')

# %%
df_wine.plot.scatter(
x='alcohol', 
y='sulphates')
pd.plotting.scatter_matrix(
df_wine[['citric acid',
'alcohol',
'sulphates']])

# %%
high = df_wine[['sulphates','alcohol']][df_wine['quality']>5]
low = df_wine[['sulphates','alcohol']][df_wine['quality']<=5]

plt.scatter(high['sulphates'],high['alcohol'],s=50,c='blue',marker='o',label='ótimo')
plt.scatter(x=low['sulphates'],y=low['alcohol'],s=50,c='red',marker='v',label='poor')


plt.xlabel('Sulphates')
plt.ylabel('Alcohol')
plt.legend()
plt.grid()
plt.show()

# %%
corr_matrix = df_wine.corr()
corr_matrix["quality"].sort_values(ascending=False)

# %%
# !pip install seaborn

# %%
import seaborn as sns

correlations = df_wine.corr()
fig, ax = plt.subplots(figsize=(10, 10))

colormap = sns.color_palette("BrBG", 10)

sns.heatmap(correlations, 
    cmap=colormap, 
    annot=True, 
    fmt=".2f")

colum_names = df_wine.columns
ax.set_yticklabels(colum_names);

plt.show()

# %% [markdown]
# ## Avaliação de carros

# %%
import pandas as pd
import requests, zipfile, os, io

url = 'https://archive.ics.uci.edu/static/public/19/car+evaluation.zip'
folder = './car_dataset'

r = requests.get(url, stream=True)
thezip = zipfile.ZipFile(io.BytesIO(r.content))
thezip.extractall(folder)

path = "car_dataset/car.data"
header = ['buying','maint','doors','persons','lug_boot','safety','class']
df_car = pd.read_csv(path, names = header)
df_car.head(5)
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df_car.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1723    0
# 1724    0
# 1725    0
# 1726    0
# 1727    0
# Length: 1728, dtype: int64

# %%
from sklearn.preprocessing import Imputer
import numpy as np
Arr = np.array([[5,3,2,2],[3,None,1,9],[5,2,7,None]])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from sklearn.preprocessing import Imputer
#       2 import numpy as np
#       3 Arr = np.array([[5,3,2,2],[3,None,1,9],[5,2,7,None]])
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/preprocessing/__init__.py)

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# ...
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np

arr = np.array([
    [5, 3, 2, 2],
    [3, np.nan, 1, 9],
    [5, 2, 7, np.nan]
    ])

imputer = SimpleImputer(strategy='median')

imputer.fit(arr)

arr_imputed = imputer.transform(arr)

arr_imputed
# Out:
# array([[5. , 3. , 2. , 2. ],
#        [3. , 2.5, 1. , 9. ],
#        [5. , 2. , 7. , 5.5]])
